# %%
0.2 + 0.1
from fractions import Fraction
Fraction(2,10) + Fraction(1,10)
# Out:
# Fraction(3, 10)

# %%
# The function "Fraction" allows the programmer to 
# input any arbitrary numerator and denominator values as 
# parameters and perform arthimetic operations on them. In this case, 
# for example, we summed up (1/10) and (2/10) to get a result of (3/10)

# %%
def computeInverseSquaresSum(numbers):
    squaresum = 0
    for i in range(len(numbers)):
        squaresum = Fraction(1,(numbers[i])**2) + squaresum
    return squaresum

# %%
computeInverseSquaresSum([2,3,6])
# Out:
# Fraction(7, 18)

# %%
def findDecomposition(frac,upperBound):
    a = [] #initialize a as an empty array
    return findDecompositionHelper(frac,2,upperBound,a) #start with 2 since 1 would result in improper fraction

def findDecompositionHelper(frac,start,upperBound,a): 
    if frac == 0: # base case for the recursive call 
        return a
    if start == upperBound: #check to see if we have reached the end case and if so, no solution is found
        return None
    
    if Fraction(1,start**2) <= frac:
        a.append(start)
        return findDecompositionHelper(frac - Fraction(1,start**2),start+1,upperBound,a) #if inverse square of start is less than fraction, then append it to a and subtract Fraction(1,start**2) from frac, iterate start
    else:
        return findDecompositionHelper(frac,start+1,upperBound,a)

    
    
#     a = []
    
#     for i in range(2,upperBound):
        
        
#         if computeInverseSquaresSum(a) == frac:
#             break
#         else if computeInverseSquaresSum(a) > frac:
            
#     return a

# def checksum(frac,a):
#     if computeInverseSquaresSum(a) == frac:
#         return True
#     else if computeInverseSquaresSum(a) < frac:
#         return False
#     else:

# %%
findDecomposition(Fraction(7,18),7)
# Out:
# [2, 3, 6]
